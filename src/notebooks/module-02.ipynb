# %% [markdown]
# # **Car Price Prediction Project**
# Plan for approaching this project:
# 1. Data preparation and exploratory data analysis
# 2. Implement a Linear Regression for predicting the price
# 3. Understand the details of Linear Regression
# 4. Evaluate the model with RMSE
# 5. Feature Engineering
# 6. Regularization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = "../../data/raw/car_dataset.csv"

# %%
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.shape
# Out:
# (11914, 16)

# %% [markdown]
# ### Data Preparation

# %%
# Standardize the name of the columns
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
# Select all string columns
string_columns = df.select_dtypes(include=["object"]).columns

# %%
# Standardize the values on the string columns
for col in string_columns:
    df[col] = [
        val.lower().replace(" ", "_") if isinstance(val, str) else val
        for val in df[col]
    ]

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
df.describe().round(2)
# Out:
#            year  engine_hp  engine_cylinders  number_of_doors  highway_mpg  \
# count  11914.00   11845.00          11884.00         11908.00     11914.00
# mean    2010.38     249.39              5.63             3.44        26.64
# std        7.58     109.19              1.78             0.88         8.86
# min     1990.00      55.00              0.00             2.00        12.00
# 25%     2007.00     170.00              4.00             2.00        22.00
# 50%     2015.00     227.00              6.00             4.00        26.00
# 75%     2016.00     300.00              6.00             4.00        30.00
# max     2017.00    1001.00             16.00             4.00       354.00
#
#        city_mpg  popularity        msrp
# count  11914.00    11914.00    11914.00
# mean      19.73     1554.91    40594.74
# std        8.99     1441.86    60109.10
# min        7.00        2.00     2000.00
# 25%       16.00      549.00    21000.00
# 50%       18.00     1385.00    29995.00
# ...

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler']
# 48
#
# model
# ['1_series_m' '1_series' '100' '124_spider' '190-class']
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel']
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# 5
#
# driven_wheels
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance']
# 71
#
# vehicle_size
# ['compact' 'midsize' 'large']
# 3
#
# vehicle_style
# ['coupe' 'convertible' 'sedan' 'wagon' '4dr_hatchback']
# 16
#
# highway_mpg
# [26 28 27 25 24]
# 59
#
# ...

# %% [markdown]
# #### Distribution of price

# %%
# %matplotlib inline

# %%
sns.histplot(df["msrp"], bins=50);

# %%
sns.histplot(df["msrp"][df["msrp"] < 100000], bins=50);

# %% [markdown]
# This kind of distribution is not good for machine learning models. So, we are going to apply a __log distribution__ to the price variable.
#
# One thing we need to be careful with the log distribution is that it does not accept zero or negative values.

# %%
# Applies natural logarithm of one plus the input array, element-wise.
prices_log = np.log1p(df["msrp"])

# %%
sns.histplot(prices_log, bins=50);

# %% [markdown]
# #### Missing values

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %% [markdown]
# ### Validation Framework - Manual Implementation
# We will use 3 steps to build the model: first, we will train the model. second, we will validate the model. And finally, we will test the model.
#
# With these approach, we will have 3 sets of data: one for training, one for validation, and one for testing.
#
# So, for this project, we will use the following split: 60% for training, 20% for validation, and 20% for testing.

# %%
n = len(df)

n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test

# %%
df_train = df.iloc[n_train:]
df_val = df.iloc[n_train : n_train + n_val]
df_test = df.iloc[n_train + n_val :]

# %%
np.random.seed(2)
idx = np.arange(n)
np.random.shuffle(idx)

# %%
idx
# Out:
# array([2735, 6720, 5878, ..., 6637, 2575, 7336], shape=(11914,))

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train : n_train + n_val]]
df_test = df.iloc[idx[n_train + n_val :]]

# %%
df.iloc[idx[:10]]
# Out:
#              make            model  year             engine_fuel_type  \
# 2735    chevrolet           cobalt  2008             regular_unleaded
# 6720       toyota           matrix  2012             regular_unleaded
# 5878       subaru          impreza  2016             regular_unleaded
# 11190  volkswagen          vanagon  1991             regular_unleaded
# 4554         ford            f-150  2017     flex-fuel_(unleaded/e85)
# 8001   volkswagen           rabbit  2008             regular_unleaded
# 2882      bentley  continental_gtc  2013  premium_unleaded_(required)
# 649           bmw         6_series  2015  premium_unleaded_(required)
# 616       maybach               57  2012  premium_unleaded_(required)
# 4459         ford   f-150_heritage  2004             regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 2735       148.0               4.0            manual  front_wheel_drive
# ...

# %%
df_train.head()
# Out:
#              make    model  year          engine_fuel_type  engine_hp  \
# 2735    chevrolet   cobalt  2008          regular_unleaded      148.0
# 6720       toyota   matrix  2012          regular_unleaded      132.0
# 5878       subaru  impreza  2016          regular_unleaded      148.0
# 11190  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4554         ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 2735                4.0            manual  front_wheel_drive              2.0
# 6720                4.0         automatic  front_wheel_drive              4.0
# 5878                4.0         automatic    all_wheel_drive              4.0
# 11190               4.0            manual   rear_wheel_drive              3.0
# 4554                8.0         automatic   four_wheel_drive              4.0
#
# ...

# %%
df_val.head()
# Out:
#                 make               model  year  \
# 2779       chevrolet            colorado  2015
# 3708   mercedes-benz             e-class  2017
# 4794            ford               focus  2017
# 10498          acura                 tlx  2016
# 1880      volkswagen  beetle_convertible  2016
#
#                      engine_fuel_type  engine_hp  engine_cylinders  \
# 2779                 regular_unleaded      200.0               4.0
# 3708      premium_unleaded_(required)      241.0               4.0
# 4794         flex-fuel_(unleaded/e85)      160.0               4.0
# 10498  premium_unleaded_(recommended)      290.0               6.0
# 1880                 regular_unleaded      170.0               4.0
#
#       transmission_type      driven_wheels  number_of_doors market_category  \
# 2779          automatic   four_wheel_drive              4.0             NaN
# 3708          automatic    all_wheel_drive              4.0          luxury
# ...

# %%
df_test.head()
# Out:
#                 make           model  year          engine_fuel_type  \
# 11195            gmc         vandura  1994          regular_unleaded
# 673    mercedes-benz       600-class  1993          regular_unleaded
# 11270         toyota           venza  2013          regular_unleaded
# 752            volvo             740  1992          regular_unleaded
# 3137            ford  crown_victoria  2010  flex-fuel_(unleaded/e85)
#
#        engine_hp  engine_cylinders transmission_type     driven_wheels  \
# 11195      165.0               6.0         automatic  rear_wheel_drive
# 673        389.0              12.0         automatic  rear_wheel_drive
# 11270      268.0               6.0         automatic   all_wheel_drive
# 752        114.0               4.0         automatic  rear_wheel_drive
# 3137       224.0               8.0         automatic  rear_wheel_drive
#
#        number_of_doors        market_category vehicle_size vehicle_style  \
# ...

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (7150, 2382, 2382)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# %%
del df_train["msrp"]
del df_val["msrp"]
del df_test["msrp"]

# %% [markdown]
# ### Linear Regression
# $$g(x_i) = w_0 + w_1 x_{i1} + w_2 x_{i2} + w_3 x_{i3} + \dots + w_n x_{in}$$
#
# $$g(x_i) = w_0 + \sum_{j=1}^{n} w_j x_{ij}$$

# %%
df_train.iloc[10]
# Out:
# make                                 rolls-royce
# model                     phantom_drophead_coupe
# year                                        2015
# engine_fuel_type     premium_unleaded_(required)
# engine_hp                                  453.0
# engine_cylinders                            12.0
# transmission_type                      automatic
# driven_wheels                   rear_wheel_drive
# number_of_doors                              2.0
# market_category        exotic,luxury,performance
# vehicle_size                               large
# vehicle_style                        convertible
# highway_mpg                                   19
# city_mpg                                      11
# popularity                                    86
# Name: 10, dtype: object

# %%
xi = [453, 11, 86]

# %%
# Linear Regression Implementation

w0 = 7.17
w = [0.01, 0.04, 0.002]


def linear_regression(xi):
    n = len(xi)
    pred = w0
    for j in range(n):
        pred = pred + w[j] * xi[j]
    return pred

# %%
linear_regression(xi)
# Out:
# 12.312

# %%
np.expm1(12.312)
# Out:
# np.float64(222347.2221101062)

# %% [markdown]
# ### Linear Regression - Vector Form
# The linear regression formula can be written in a much more concisely way using the vectorized form:
#
# $$h_\theta(X) = X\theta$$
#
# $h_\theta(X)$ is the hypothesis function, using the parameters $\theta$.
#
# $\theta$ is the model's parameter vector, containing the bias term and the feature weights.
#
# $x$ is the instance's feature vector
#
# $\theta * x$ is the dot product of the vectors $\theta$ and $x$.
#
# In ML, vectors are often represented as _column vectors_, which are 2D arrays with a single column. If $\theta$ and $x$ are column vectors, the the prediction is $\hat{y} = \theta^T x$, where $\theta^T$ is the transpose of $\theta$ (row vector) and $\theta^Tx$ is the matrix multiplication of $\theta^T$ and $x$.
#
# Now that we know about linear regression, we need to know how to train it. First, training a model means setting its parameters so that the model best fits the training set. For this, we need a measure, like RMSE, of how well the model fits the data. For a regression model, we need to find a value of $\theta$ that minimizes the RMSE.
#
# Below we have the formula for the MSE. With that, we can easily calculate the RMSE - that is just the square root of the MSE.
# $$\text{MSE}(\mathbf{X}, \mathbf{y}, h_{\boldsymbol{\theta}}) = \frac{1}{m} \sum_{i=1}^{m} \left( \boldsymbol{\theta}^\top \mathbf{x}^{(i)} - y^{(i)} \right)^2$$
#
# Now, to find the value of $\theta$ that minimizes the MSE, we will be using the __normal equation__.
# $$\hat{\boldsymbol{\theta}} = (\mathbf{X}^\top \mathbf{X})^{-1} \mathbf{X}^\top \mathbf{y}$$
# Where:
# - $\hat{\boldsymbol{\theta}}$ is the value of $\theta$ that minimizes the cost function.
# - $\mathbf{y}$ is the vector of target values.

# %%
w_new = [w0] + w

# %%
w_new
# Out:
# [7.17, 0.01, 0.04, 0.002]

# %%
def linear_regression(xi):
    xi = [1] + xi
    return np.dot(xi, w_new)

# %%
linear_regression(xi)
# Out:
# np.float64(12.312)

# %%
x1 = [1, 148, 24, 1385]
x2 = [1, 132, 25, 2031]
x10 = [1, 453, 11, 86]
X = [x1, x2, x10]
X = np.array(X)

# %%
X
# Out:
# array([[   1,  148,   24, 1385],
#        [   1,  132,   25, 2031],
#        [   1,  453,   11,   86]])

# %%
w0 = 7.17
w = [0.01, 0.04, 0.002]
w_new = [w0] + w

# %%
X.dot(w_new)
# Out:
# array([12.38 , 13.552, 12.312])

# %%
# Linear Looking data to test the equation
np.random.seed(42)
m = 500
X = 2 * np.random.rand(m, 1)  # Column Vector
y = 4 + 3 * X + np.random.randn(m, 1)  # Column Vector

# %%
plt.scatter(X, y);

# %% [markdown]
# Now is the time where we compute the Normal Equation. We'll use the `inv()` function from Numpy to compute the inverse of a matrix, and the `dot()` method for matrix multiplication.

# %%
from sklearn.preprocessing import add_dummy_feature

X_b = add_dummy_feature(X)  # Add x0=1 to each instance
theta_best = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y

# %%
theta_best
# Out:
# array([[3.89294835],
#        [3.11500231]])

# %%
# Lets make some predictions
X_new = np.array([[0], [2]])
X_new_b = add_dummy_feature(X_new)
y_predict = X_new_b @ theta_best
y_predict
# Out:
# array([[ 3.89294835],
#        [10.12295298]])

# %%
# Now, plotting this model's prediction
plt.plot(X_new, y_predict, "r-", label="Predictions")
plt.plot(X, y, "b.")
plt.show();

# %%
# Now, we will apply linear regression using Scikit-learn
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_  # Bias term and feature weights, respectivelly
# Out:
# (array([3.89294835]), array([[3.11500231]]))

# %%
lin_reg.predict(X_new)
# Out:
# array([[ 3.89294835],
#        [10.12295298]])

# %% [markdown]
# ### Training a Linear Regression Model

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])
    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)

    return w_full[0], w_full[1:]

# %% [markdown]
# ### Car Price Baseline Model

# %%
df_train.head()
# Out:
#          make    model  year          engine_fuel_type  engine_hp  \
# 0   chevrolet   cobalt  2008          regular_unleaded      148.0
# 1      toyota   matrix  2012          regular_unleaded      132.0
# 2      subaru  impreza  2016          regular_unleaded      148.0
# 3  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4        ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#    engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0               4.0            manual  front_wheel_drive              2.0
# 1               4.0         automatic  front_wheel_drive              4.0
# 2               4.0         automatic    all_wheel_drive              4.0
# 3               4.0            manual   rear_wheel_drive              3.0
# 4               8.0         automatic   four_wheel_drive              4.0
#
#   market_category vehicle_size      vehicle_style  highway_mpg  city_mpg  \
# ...

# %%
df_train.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity'],
#       dtype='object')

# %%
# Select base features for the model
base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']
df_train[base].head()
# Out:
#    engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity
# 0      148.0               4.0           33        24        1385
# 1      132.0               4.0           32        25        2031
# 2      148.0               4.0           37        28         640
# 3       90.0               4.0           18        16         873
# 4      385.0               8.0           21        15        5657

# %%
# Takes all the values of the base features
X_train = df_train[base].values

# %%
# Replaces NA values with 0 values
X_train = df_train[base].fillna(0).values

# %%
# Apply the linear regression model
w0, w = train_linear_regression(X_train, y_train)

# %%
y_pred = w0 + X_train.dot(w)

# %%
y_pred
# Out:
# array([ 9.54792783,  9.38733977,  9.67197758, ..., 10.30423015,
#        11.9778914 ,  9.99863111], shape=(7150,))

# %%
sns.histplot(y_pred, color='red', bins=50, alpha=0.5, label='Predictions')
sns.histplot(y_train, color='blue', bins=50, alpha=0.5, label='Target')
plt.legend();

# %% [markdown]
# ### RMSE

# %%
def rmse(y, y_pred):
    sqerr = (y - y_pred) ** 2
    mse = sqerr.mean()
    rmse = np.sqrt(mse)
    return rmse

# %%
rmse(y_train, y_pred)
# Out:
# np.float64(0.7554192603920132)

# %% [markdown]
# ### Validating the Model

# %%
def prepare_X(df):
    df_num = df[base]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
# Training step
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

# Validation step
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# np.float64(0.761653099130156)

# %% [markdown]
# ### Very Simple Feature Engineering

# %%
2017 - df_train.year
# Out:
# 0        9
# 1        5
# 2        1
# 3       26
# 4        0
#         ..
# 7145     2
# 7146     2
# 7147     2
# 7148     3
# 7149     0
# Name: year, Length: 7150, dtype: int64

# %%
def prepare_X(df):
    df = df.copy()
    df['age'] = 2017 - df.year
    features = base + ['age']
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# age                    int64
# dtype: object

# %%
# Training step
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

# Validation step
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# np.float64(0.5172055461058299)

# %%
sns.histplot(y_pred, color='red', bins=50, alpha=0.5, label='Predictions')
sns.histplot(y_val, color='blue', bins=50, alpha=0.5, label='Target')
plt.legend();

# %% [markdown]
# ### Categorical Variables

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
df_train.number_of_doors.isnull().sum()
# Out:
# np.int64(6)

# %%
df_train.number_of_doors.unique()
# Out:
# array([ 2.,  4.,  3., nan])

# %%
for v in [2, 3, 4]:
    df_train['number_of_doors_%s' % v] = (df_train.number_of_doors == v).astype('int')

# We could also use the code below for the same purpose:
# df_train = pd.get_dummies(df_train, columns=['number_of_doors'], dtype=int)

# %%
df_train.head()
# Out:
#          make    model  year          engine_fuel_type  engine_hp  \
# 0   chevrolet   cobalt  2008          regular_unleaded      148.0
# 1      toyota   matrix  2012          regular_unleaded      132.0
# 2      subaru  impreza  2016          regular_unleaded      148.0
# 3  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4        ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#    engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0               4.0            manual  front_wheel_drive              2.0
# 1               4.0         automatic  front_wheel_drive              4.0
# 2               4.0         automatic    all_wheel_drive              4.0
# 3               4.0            manual   rear_wheel_drive              3.0
# 4               8.0         automatic   four_wheel_drive              4.0
#
#   market_category vehicle_size      vehicle_style  highway_mpg  city_mpg  \
# ...

# %%
def prepare_X(df):
    df = df.copy()
    df['age'] = 2017 - df.year
    features = base.copy()
    features.append('age')

    for v in [2, 3, 4]:
        df_train['number_of_doors_%s' % v] = (df_train.number_of_doors == v).astype('int')
        features.append('number_of_doors_%s' % v)
    
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X
